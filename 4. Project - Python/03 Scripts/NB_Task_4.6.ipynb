# %% [markdown]
# # Working on the tasks of 4.6
#
# #### 1. Import Libraries
# #### 2. Import DFs
# #### 3. Workin on the Directions
# #### 4. Exporting the Dataframe

# %% [markdown]
# ## 1. Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## 2. Import DFs

# %%
# Import Dataframes

path = r'X:\Data_Analytic\JUPYTER\Instacart Basket Analysis'

df_ords_prods_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
df_prods_checked = pd.read_csv(os.path.join( path, '02 Data', 'Prepared Data', 'products_checked.csv'))

# %% [markdown]
# ## 3. Working on the Directions

# %% [markdown]
# ### Direction 4

# %%
df_ords_prods_combined.shape

# The shape is equal.
# Out:
# (32434489, 12)

# %% [markdown]
# ### Direction 5

# %%
df_prods_checked.head()
# Out:
#    Unnamed: 0  product_id                                       product_name  \
# 0           0           1                         Chocolate Sandwich Cookies
# 1           1           2                                   All-Seasons Salt
# 2           2           3               Robust Golden Unsweetened Oolong Tea
# 3           3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4           4           5                          Green Chile Anytime Sauce
#
#    aisle_id  department_id  prices
# 0        61             19     5.8
# 1       104             13     9.3
# 2        94              7     4.5
# 3        38              1    10.5
# 4         5             13     4.3

# %%
df_ords_prods_combined.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 0           0             0   2539329        1             1
# 1           0             0   2539329        1             1
# 2           0             0   2539329        1             1
# 3           0             0   2539329        1             1
# 4           0             0   2539329        1             1
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order  product_id  \
# 0                   2                  8                    -1.0         196
# 1                   2                  8                    -1.0       14084
# 2                   2                  8                    -1.0       12427
# 3                   2                  8                    -1.0       26088
# 4                   2                  8                    -1.0       26405
#
#    add_to_cart_order  reordered _merge
# 0                  1          0   both
# 1                  2          0   both
# ...

# %% [markdown]
# ##### Explanation, the '-1' in the 'days_since_prior_order' stem from a correction I did, before receiving my results on the last task. In the meantime, I realised, that giving the NaN a 0 could indicate the wrong information. I want to make clear, that this is the customers very first order, by changing the NaN to a '-1'. So I corrected it, but thought that maybe it isn't that big of a problem and did not resubmit my correction.

# %%
df_ords_prods_combined.tail()
# Out:
#           Unnamed: 0  Unnamed: 0.1  order_id  user_id  order_number  \
# 32434484     3421081       3421081   2977660   206209            13
# 32434485     3421081       3421081   2977660   206209            13
# 32434486     3421081       3421081   2977660   206209            13
# 32434487     3421081       3421081   2977660   206209            13
# 32434488     3421081       3421081   2977660   206209            13
#
#           orders_day_of_week  order_hour_of_day  days_since_prior_order  \
# 32434484                   1                 12                     7.0
# 32434485                   1                 12                     7.0
# 32434486                   1                 12                     7.0
# 32434487                   1                 12                     7.0
# 32434488                   1                 12                     7.0
#
#           product_id  add_to_cart_order  reordered _merge
# 32434484       14197                  5          1   both
# ...

# %%
df_ords_prods_combined_dropped = df_ords_prods_combined.drop(['Unnamed: 0', 'Unnamed: 0.1'], axis=1)

# %% [markdown]
# ##### I believe that due to the merging of the previously dataframes, the 'Unnamed: 0' and 'Unnamed: 0.1' dataframes might be the indexes. Anyway, I dropped them under a new variable.

# %%
df_ords_prods_combined_dropped.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    -1.0         196                  1          0   both
# 1                    -1.0       14084                  2          0   both
# 2                    -1.0       12427                  3          0   both
# 3                    -1.0       26088                  4          0   both
# 4                    -1.0       26405                  5          0   both

# %% [markdown]
# ##### Furthermore I'm going to rename the '_merge' column, so that it's understandable that this column stems from the first merge.

# %%
df_ords_prods_combined_dropped.rename(columns={'_merge' : 'first_m'})
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                    -1.0         196
# 1                         8                    -1.0       14084
# ...

# %%
df_ords_prods_combined_dropped.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                    -1.0         196                  1          0   both
# 1                    -1.0       14084                  2          0   both
# 2                    -1.0       12427                  3          0   both
# 3                    -1.0       26088                  4          0   both
# 4                    -1.0       26405                  5          0   both

# %% [markdown]
# ##### I also dropped the 'Unnamed: 0' column from the df_prods_checked dataframe

# %%
df_prods_checked_dropped = df_prods_checked.drop(['Unnamed: 0'], axis=1)

# %%
df_prods_checked_dropped.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %% [markdown]
# ### Merging the two dataframes

# %%
df_merged_inner = df_ords_prods_combined_dropped.merge(df_prods_checked_dropped, on = 'product_id', indicator = 'Second_Merge')

#df_merged_full = df_ords_prods_combined_dropped.merge(df_prods_checked_dropped, on = 'product_id', how = 'outer')

# %%
df_merged_full = df_ords_prods_combined_dropped.merge(df_prods_checked_dropped, on = 'product_id', how = 'outer', indicator = 'Second_Merge')

# %%
df_merged_inner.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    -1.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices Second_Merge
# ...

# %%
df_merged_full.head()
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0  2539329.0      1.0           1.0                 2.0                8.0
# 1  2398795.0      1.0           2.0                 3.0                7.0
# 2   473747.0      1.0           3.0                 3.0               12.0
# 3  2254736.0      1.0           4.0                 4.0                7.0
# 4   431534.0      1.0           5.0                 4.0               15.0
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                    -1.0         196                1.0        0.0   both
# 1                    15.0         196                1.0        1.0   both
# 2                    21.0         196                1.0        1.0   both
# 3                    29.0         196                1.0        1.0   both
# 4                    28.0         196                1.0        1.0   both
#
#   product_name  aisle_id  department_id  prices Second_Merge
# ...

# %% [markdown]
# ### Direction 6

# %%
df_merged_full['Second_Merge'].value_counts()
# Out:
# both          32404859
# left_only        30200
# right_only          11
# Name: Second_Merge, dtype: int64

# %%
df_merged_inner['Second_Merge'].value_counts()
# Out:
# both          32404859
# left_only            0
# right_only           0
# Name: Second_Merge, dtype: int64

# %% [markdown]
# ##### As I checked the full_merge data frame I wanted to know what I'm dealing with exactly, so I created 2 subsets and looked at them

# %%
df_merged_full_left = df_merged_full[df_merged_full['Second_Merge'] == 'left_only']

# %%
df_merged_full_right = df_merged_full[df_merged_full['Second_Merge'] == 'right_only']

# %%
df_merged_full_left
# Out:
#            order_id   user_id  order_number  orders_day_of_week  \
# 12039117     7099.0      27.0          63.0                 3.0
# 12039118  1837192.0      27.0          80.0                 2.0
# 12039119  2915432.0     298.0           1.0                 4.0
# 12039120   613874.0     298.0           3.0                 1.0
# 12039121   690386.0     479.0           1.0                 3.0
# ...             ...       ...           ...                 ...
# 32413293  1514902.0  179816.0           4.0                 5.0
# 32413294  3287190.0  179816.0           5.0                 6.0
# 32413295  2943026.0  179816.0           8.0                 0.0
# 32413296  2108832.0  179816.0          15.0                 2.0
# 32413297  1077336.0  202849.0          52.0                 1.0
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 12039117               10.0                     1.0        6799
# 12039118                8.0                     6.0        6799
# ...

# %%
df_merged_full_right
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 32435059       NaN      NaN           NaN                 NaN
# 32435060       NaN      NaN           NaN                 NaN
# 32435061       NaN      NaN           NaN                 NaN
# 32435062       NaN      NaN           NaN                 NaN
# 32435063       NaN      NaN           NaN                 NaN
# 32435064       NaN      NaN           NaN                 NaN
# 32435065       NaN      NaN           NaN                 NaN
# 32435066       NaN      NaN           NaN                 NaN
# 32435067       NaN      NaN           NaN                 NaN
# 32435068       NaN      NaN           NaN                 NaN
# 32435069       NaN      NaN           NaN                 NaN
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 32435059                NaN                     NaN        3630
# 32435060                NaN                     NaN        3718
# ...

# %% [markdown]
# ##### As we can see, there probably are 11 products which haven't been ordered at all or are mistakes and there are probably 30200 customers who ordered something that doesn't exist in the database or are mistakes as well. But since these mistakes are so little, I will ignore them and use the inner joined dataframe.

# %% [markdown]
# ## 4. Exporting the Dataframe / Direction 7

# %%
df_merged_inner.shape
# Out:
# (32404859, 15)

# %%
df_merged_inner.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))
